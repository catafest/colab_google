# %% [markdown]
# <a href="https://colab.research.google.com/github/catafest/colab_google/blob/master/catafest_039.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *News API is a simple, easy-to-use REST API that returns JSON search results for current and historic news articles published by over 80,000 worldwide sources.*
#
# Price starts from  - developer $0
#
# Read more at [documentation for newsapi](https://newsapi.org/docs).

# %%
# !pip install newsapi-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Let use [this NewsApiClient python package](https://github.com/mattlisiv/newsapi-python) :

# %%
from newsapi import NewsApiClient

from IPython.display import IFrame,clear_output
clear_output()

# %% [markdown]
# You need to get your api key from [your account](https://newsapi.org/account).

# %%
api_key = input('Fill with api key !')

api = NewsApiClient(api_key=api_key)

# %% [markdown]
# Search news by words. I used these: *news Europe*

# %%
api.get_everything(q='news Europe')
# Out:
# {'status': 'ok',
#  'totalResults': 13747,
#  'articles': [{'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Mindy Weisberger',
#    'title': 'Earliest evidence of hallucinogenic drug use in Europe found in ancient human hairs',
#    'description': 'Scientists have discovered direct evidence that people in Europe used psychoactive drugs during the Bronze Age, possibly as part of ancient rituals.',
#    'url': 'https://www.cnn.com/2023/04/10/world/ancient-drug-use-hair-europe-scn/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230407132456-01-ancient-hair-drug-use-europe-illo.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-04-10T11:54:59Z',
#    'content': 'Editors Note: Sign up for CNNs Wonder Theory science newsletter. Explore the universe with news on fascinating discoveries, scientific advancements and more.\r\nScientists have discovered direct eviden… [+5197 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
# ...

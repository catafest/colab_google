# %% [markdown]
# <a href="https://colab.research.google.com/github/catafest/colab_google/blob/master/python_imdb_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a simple example about how you can use the colab google features with python module imdbpy.
#
# The source code is very simple to understand.

# %%
pip install imdbpy
# Out:
# ...
#      |████████████████████████████████| 296kB 4.8MB/s
# ...

# %%
from imdb import IMDb 
imdb = IMDb()
top_movies = imdb.get_top250_movies()
top_movies = [imdb.get_movie(movie.movieID) for movie in top_movies[:20]]
print(top_movies)
# Out:
# [<Movie id:0111161[http] title:_The Shawshank Redemption (1994)_>, <Movie id:0068646[http] title:_The Godfather (1972)_>, <Movie id:0071562[http] title:_The Godfather: Part II (1974)_>, <Movie id:0468569[http] title:_The Dark Knight (2008)_>, <Movie id:0050083[http] title:_12 Angry Men (1957)_>, <Movie id:0108052[http] title:_Schindler's List (1993)_>, <Movie id:0167260[http] title:_The Lord of the Rings: The Return of the King (2003)_>, <Movie id:0110912[http] title:_Pulp Fiction (1994)_>, <Movie id:0060196[http] title:_The Good, the Bad and the Ugly (1966)_>, <Movie id:0120737[http] title:_The Lord of the Rings: The Fellowship of the Ring (2001)_>, <Movie id:0137523[http] title:_Fight Club (1999)_>, <Movie id:0109830[http] title:_Forrest Gump (1994)_>, <Movie id:1375666[http] title:_Inception (2010)_>, <Movie id:0080684[http] title:_Star Wars: Episode V - The Empire Strikes Back (1980)_>, <Movie id:0167261[http] title:_The Lord of the Rings: The Two Towers (2002)_>, <Movie id:01330
# ...

# %%
{movie['title']:{'genres':movie['genres'], 'actors':movie['cast']} for movie in top_movies}
# Out:
# {'12 Angry Men': {'actors': [<Person id:0000842[http] name:_Martin Balsam_>,
#    <Person id:0275835[http] name:_John Fiedler_>,
#    <Person id:0002011[http] name:_Lee J. Cobb_>,
#    <Person id:0550855[http] name:_E.G. Marshall_>,
#    <Person id:0001430[http] name:_Jack Klugman_>,
#    <Person id:0083081[http] name:_Edward Binns_>,
#    <Person id:0912001[http] name:_Jack Warden_>,
#    <Person id:0000020[http] name:_Henry Fonda_>,
#    <Person id:0842137[http] name:_Joseph Sweeney_>,
#    <Person id:0003225[http] name:_Ed Begley_>,
#    <Person id:0903667[http] name:_George Voskovec_>,
#    <Person id:0916434[http] name:_Robert Webber_>,
#    <Person id:0094036[http] name:_Rudy Bond_>,
#    <Person id:0331131[http] name:_Tom Gorman_>,
#    <Person id:0446450[http] name:_James Kelly_>,
#    <Person id:0625180[http] name:_Billy Nelson_>,
#    <Person id:0767847[http] name:_John Savoca_>,
#    <Person id:0830818[http] name:_Walter Stocker_>],
#   'genres': ['Drama']},
# ...
